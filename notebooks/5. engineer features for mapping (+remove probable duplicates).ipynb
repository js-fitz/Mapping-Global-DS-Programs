# %% [markdown]
# ## add custom data, generate tooltips & drop probable duplicates
#
# ---

# %%
import os
import time

import geopandas
import numpy as np
import pandas as pd
from fuzzywuzzy import fuzz
from tqdm.notebook import tqdm
flatten = lambda l: [i for s in l for i in s]

# %%
# %%capture
# %%tqdm.pandas()

# %% [markdown]
# ### read data

# %%
boot_locs = pd.read_csv('boot_locs.csv')
uni_locs = pd.read_csv('degs_gcoded.csv')
len(boot_locs), len(uni_locs)
# Out:
# (973, 2740)

# %% [markdown]
# # --> add more data here <--

# %%
boot_locs = pd.concat([boot_locs,
                       
                      # additional bootcamp data here <----
                       
                      ]).reset_index(drop=True)

uni_locs = pd.concat([uni_locs,
                      
                      # additional college data here <-----
                      
                      ]).reset_index(drop=True)

# %% [markdown]
# ---
#
# ## Format features for tooltips (University data)

# %%
online_map = {'No': 'In Person', 'Yes': 'Online', 'Blended':'In Person + Online (blended)'}
uni_locs.online = uni_locs.online.map(online_map)

# %%
def parse_enroll(en):
    splt = str(en).split(' & ')
    if len(splt)==1: return en
    return ' & '.join(set(splt))
uni_locs.enrollment = uni_locs.enrollment.apply(parse_enroll).value_counts()

# %%
uni_locs.dropna(subset=['latitude'], inplace=True)

for row in uni_locs.index:
    
    dp = uni_locs.loc[row, 'dur_period']
    dn = uni_locs.loc[row, 'dur_number']
       
    try:
        dn = int(dn) # adjust months/yeasr
        if dn<=18:
            leng = f'{int(dn)}'
            dp = 'month'
        else:
            leng = f'{round(int(dn)/12, 1)}'.rstrip('.0')
            dp = 'year'

        uni_locs.loc[row, 'duration'] = f'{leng} {dp}s'            
    
    except:
        uni_locs.loc[row, 'duration'] = f'(?)'
        
    deg_spec = uni_locs.loc[row, 'degree'] # pretty degree
    deg_class = uni_locs.loc[row, 'class']
    commitment = uni_locs.loc[row, 'enrollment']
    commitment = (str(commitment)+' ') if 'nan'!=str(commitment).lower()!='(?)' else ''
    online = uni_locs.loc[row, 'online']  
    online = '| '+str(online) if 'nan'!=str(online).lower()!='(?)' else ''
    if str(deg_spec).lower()!='nan' and deg_spec[:5].lower() != deg_class[:5].lower():
        uni_locs.loc[row, 'pretty_degree'] = f'<b>{commitment}{deg_class} ({deg_spec})</b> {online}'
    else:
        uni_locs.loc[row, 'pretty_degree'] = f'<b>{commitment}{deg_class} </b> {online}'
    
uni_locs = uni_locs.fillna('(?)')

# %%
uni_locs.pretty_degree.value_counts().sample(10)
# Out:
# <b>Bachelor's </b> | In Person + Online (blended)            7
# <b>Master's (M.Eng.)</b> | In Person + Online (blended)      1
# <b>Master's (M.A.)</b> | In Person                          36
# <b>Bachelor's (B.Sc.)</b> | In Person                      610
# <b>Master's (M.Litt.)</b> | In Person                        3
# <b>Ph.D. </b> | In Person + Online (blended)                 2
# <b>Master's (M.Sc.)</b> | Online                            46
# <b>Master's (M.A.)</b> | In Person + Online (blended)        2
# <b>Master's (M.B.A.)</b> | In Person                        15
# <b>Bachelor's (B.A.)</b> | In Person                        80
# Name: pretty_degree, dtype: int64

# %% [markdown]
# #### fix online indicator:

# %%
for ridx in uni_locs.index:
    
    if 'online' in uni_locs.loc[ridx, 'course_name'].lower():
        uni_locs.loc[ridx, 'online'] = 'Yes'

# %% [markdown]
# ## add custom degrees data from African countries

# %%
pd.read_csv('africa_degs.csv',)[uni_locs.columns]
# Out:
#                                 course_name  \
# 0  African Master’s in Machine Intelligence
# 1  African Master’s in Machine Intelligence
# 2  African Master’s in Machine Intelligence
# 3  African Master’s in Machine Intelligence
# 4  African Master’s in Machine Intelligence
# 5  African Master’s in Machine Intelligence
# 6  Data Analytics and Business Intelligence
#
#                                    institution                  location  \
# 0  African Institute for Mathematical Sciences           Limbe, Cameroon
# 1  African Institute for Mathematical Sciences             Biriwa, Ghana
# 2  African Institute for Mathematical Sciences            MBour, Sénégal
# 3  African Institute for Mathematical Sciences  Muizenberg, South Africa
# 4  African Institute for Mathematical Sciences        Bagamoyo, Tanzania
# 5  African Institute for Mathematical Sciences            Kigali, Rwanda
# 6               University of the Western Cape   Cape Town, South Africa
#
#    description     cost  dur_period  dur_number     class  degree enrollment  \
# 0          NaN      (?)         NaN         NaN  Master's     NaN  Full-time
# 1          NaN      (?)         NaN         NaN  Master's     NaN  Full-time
# 2          NaN      (?)         NaN         NaN  Master's     NaN  Full-time
# 3          NaN      (?)         NaN         NaN  Master's     NaN  Full-time
# 4          NaN      (?)         NaN         NaN  Master's     NaN  Full-time
# 5          NaN      (?)         NaN         NaN  Master's     NaN  Full-time
# 6          NaN  R50 000         NaN         NaN  Master's     NaN  Part-time
#
#       online in_person blended_learning  geo_search  gmaps_info  coord  \
# 0  In Person       Yes               No         NaN         NaN    NaN
# 1  In Person       Yes               No         NaN         NaN    NaN
# 2  In Person       Yes               No         NaN         NaN    NaN
# 3  In Person       Yes               No         NaN         NaN    NaN
# 4  In Person       Yes               No         NaN         NaN    NaN
# 5  In Person       Yes               No         NaN         NaN    NaN
# 6  In Person       Yes               No         NaN         NaN    NaN
#
#     latitude  longitude   duration  \
# 0   4.019991   9.196396     1 year
# 1   5.168048  -1.144657     1 year
# 2  14.392066  16.958084     1 year
# 3 -34.107178  18.470513     1 year
# 4  -6.445638  38.898731     1 year
# 5  -1.961283  30.112964     1 year
# 6 -33.933529  18.628591  18 months
#
#                                        pretty_degree
# 0  <b>Full-time Master's (AMMI)</b> | In Person &...
# 1  <b>Full-time Master's (AMMI)</b> | In Person &...
# 2  <b>Full-time Master's (AMMI)</b> | In Person &...
# 3  <b>Full-time Master's (AMMI)</b> | In Person &...
# 4  <b>Full-time Master's (AMMI)</b> | In Person &...
# 5  <b>Full-time Master's (AMMI)</b> | In Person &...
# 6              <b>Part-time Master's</b> | In Person

# %%
# I generated this data manually through research:
a_degs = pd.read_csv('african_masters_degs.csv',)[uni_locs.columns]

uni_locs = pd.concat([uni_locs, a_degs]).reset_index(drop=True)

a_boot = pd.read_csv('africa_boots.csv',)[boot_locs.columns]
boot_locs = pd.concat([boot_locs, a_boot]).reset_index(drop=True)


uni_locs.latitude = uni_locs.latitude.astype(float)
uni_locs.longitude = uni_locs.longitude.astype(float)

boot_locs.latitude = boot_locs.latitude.astype(float)
boot_locs.longitude = boot_locs.longitude.astype(float)

# %% [markdown]
# ---
#
# ## Format features for tooltips (Bootcamp data)

# %%
boot_locs['pretty_camp'] = '<b>'+boot_locs['Commitment'].fillna('').apply(lambda x: x.replace(' ', '-' ).capitalize()
                                        )+ ' Bootcamp</b> | ' + boot_locs['Course Type'].fillna('')
boot_locs = boot_locs.fillna('(?)')

# %%
# drop bootcamps without one of these terms in the title

def topic_check(c):
    c = c.lower().replace('-', ' ')
    
    hot_words = ['data', 'stat', 'analy', 'busin', 'python'
                 'intell', 'informat', 'fintech', 'cybersecur',
                 'machine learn', 'machine-learn', 'optimiz',
                 'geosp', 'ter sci', 'guage proc']
    
    if any(kword in c for kword in hot_words):
        return True
    return False

for row_idx in boot_locs.index:
    c_name = boot_locs.loc[row_idx, 'course_name']
    if not topic_check(c_name): boot_locs.drop(row_idx, inplace=True)

# %% [markdown]
# ---
#
# ## final duplicates check:

# %% [markdown]
# universities are the main problem

# %%
##### drop english language courses
uni_locs = uni_locs[~uni_locs.course_name.str.contains('English Language')]

# isolatae african progs (to save because manually added)
african_progs = uni_locs[uni_locs.institution=='African Institute for Mathematical Sciences']

# %%
len(uni_locs) + len(boot_locs)
# Out:
# 3387

# %%
# check for duplicates

verb = False # activate for tuning

def parse_title(title):
    title = str(title).split('(')[0].lower()
    return title

dropped = 0
scanned = 0
for ridx in uni_locs.index: # compare each uni program against all others
    scanned += 1 # to print progress 
    if ridx not in uni_locs.index: continue # already dropped
    
    # parameters to compare:
    rcourse = parse_title(uni_locs.loc[ridx, 'course_name']) # track name
    rinst = uni_locs.loc[ridx, 'institution']
    rclass = uni_locs.loc[ridx, 'class'] # bachelors, masters or phd
    blat = round(uni_locs.loc[ridx, 'latitude'], 3) # generalized location
    blng = round(uni_locs.loc[ridx, 'latitude'], 3)
    
    if 'African Institute for Mathematical Sciences' in rinst: continue
        # these were all manually added and should be preserved
    
    for cidx in uni_locs.drop(ridx).index:
        if ridx not in uni_locs.index: continue # (already dropped, don't check)
        
        # parameters to compare:
        ccourse = parse_title(uni_locs.loc[cidx, 'course_name'])
        cinst = uni_locs.loc[cidx, 'institution']
        cclass = uni_locs.loc[cidx, 'class']
        clat = round(uni_locs.loc[cidx, 'latitude'], 3) # same general location
        clng = round(uni_locs.loc[cidx, 'latitude'], 3)
        
        # combined match ratios:
        if fuzz.ratio(rinst, cinst) > 95 and rclass==cclass:
            if fuzz.partial_ratio(rcourse, ccourse) > 95:
                if blat==blng and clat==clng:
                    rnan = uni_locs.loc[ridx].isna().sum() + (uni_locs.loc[ridx]=='(?)').sum()
                    cnan = uni_locs.loc[cidx].isna().sum() + (uni_locs.loc[cidx]=='(?)').sum()
                    if rnan>cnan:
                        uni_locs.drop(ridx, inplace=True)
                        keeping = f'{cclass[:2]}: {ccourse} ({cinst}) - ({cnan} NA)'
                        dropping = f'{rclass[:2]}: {rcourse} ({rinst}) - ({rnan} NA)'
                    else:
                        uni_locs.drop(cidx, inplace=True)
                        dropping = f'{cclass[:2]}: {ccourse} ({cinst}) - ({cnan} NA)'
                        keeping = f'{rclass[:2]}: {rcourse} ({rinst}) - ({rnan} NA)'
                    dropped +=1
                    
                    if verb:
                        print('keeping:', keeping)
                        print('dropping:', dropping)
                        print('—'*80)
    
    if ridx%10==0 and not verb:
        print(f'\rDropped: {dropped} | Scanned: {scanned}/{len(uni_locs)+dropped}', end='')
# Out:
# Dropped: 0 | Scanned: 1/2735
# /usr/local/anaconda3/envs/dsplay/lib/python3.8/site-packages/pandas/core/frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# Dropped: 274 | Scanned: 2712/2735

# %% [markdown]
# # SAVE

# %%
uni_locs.to_csv('degs_to_map.csv', index=False)
boot_locs.to_csv('boot_to_map.csv', index=False)

# %%
len(uni_locs) + len(boot_locs)
# Out:
# 3112

# %%
uni_locs
# Out:
#                                             course_name  \
# 0     Business Administration, Concentration in Mana...
# 1                               Information Engineering
# 2                               Health Care Informatics
# 3     Information Systems Technology - Information S...
# 4       Mathematics Operational Research and Statistics
# ...                                                 ...
# 2738           African Master’s in Machine Intelligence
# 2739           African Master’s in Machine Intelligence
# 2740           African Master’s in Machine Intelligence
# 2741           African Master’s in Machine Intelligence
# 2742           African Master’s in Machine Intelligence
#
#                                       institution  \
# 0                       San José State University
# 1          Hamburg University of Applied Sciences
# 2              University of Illinois Springfield
# 3                               Regent University
# 4                              Cardiff University
# ...                                           ...
# 2738  African Institute for Mathematical Sciences
# 2739  African Institute for Mathematical Sciences
# 2740  African Institute for Mathematical Sciences
# 2741  African Institute for Mathematical Sciences
# 2742  African Institute for Mathematical Sciences
#
#                                   location  \
# 0      San Jose, California, United States
# 1                         Hamburg, Germany
# 2     Springfield, Illinois, United States
# 3                                   Online
# 4           Cardiff, Wales, United Kingdom
# ...                                    ...
# 2738                         Biriwa, Ghana
# 2739                        MBour, Sénégal
# 2740              Muizenberg, South Africa
# 2741                    Bagamoyo, Tanzania
# 2742                        Kigali, Rwanda
#
#                                             description               cost  \
# 0     Business Administration, Concentration in Mana...   4,963 EUR / year
# 1     Today‘s complex information processing systems...       0 EUR / year
# 2     The Health Care Informatics bachelor’s degree ...  26,437 EUR / year
# 3     The Bachelor of Science in Information Systems...   496 EUR / credit
# 4     Combine statistics and operational research wi...  24,160 EUR / year
# ...                                                 ...                ...
# 2738                                                NaN                (?)
# 2739                                                NaN                (?)
# 2740                                                NaN                (?)
# 2741                                                NaN                (?)
# 2742                                                NaN                (?)
#
#      dur_period dur_number       class degree enrollment     online in_person  \
# 0         month         48  Bachelor's  B.Sc.        (?)  In Person        No
# 1         month         36  Bachelor's  B.Sc.        (?)  In Person        No
# 2         month         48  Bachelor's  B.Sc.        (?)  In Person        No
# 3         month         48  Bachelor's  B.Sc.        (?)  In Person        No
# 4         month         36  Bachelor's  B.Sc.        (?)  In Person        No
# ...         ...        ...         ...    ...        ...        ...       ...
# 2738        NaN        NaN    Master's    NaN  Full-time  In Person       Yes
# 2739        NaN        NaN    Master's    NaN  Full-time  In Person       Yes
# 2740        NaN        NaN    Master's    NaN  Full-time  In Person       Yes
# 2741        NaN        NaN    Master's    NaN  Full-time  In Person       Yes
# 2742        NaN        NaN    Master's    NaN  Full-time  In Person       Yes
#
#      blended_learning                                         geo_search  \
# 0                  No  San José State University, San Jose, Californi...
# 1                  No  Hamburg University of Applied Sciences, Hambur...
# 2                  No  University of Illinois Springfield, Springfiel...
# 3                  No                          Regent University, Online
# 4                  No  Cardiff University, Cardiff, Wales, United Kin...
# ...               ...                                                ...
# 2738               No                                                NaN
# 2739               No                                                NaN
# 2740               No                                                NaN
# 2741               No                                                NaN
# 2742               No                                                NaN
#
#                                              gmaps_info  \
# 0     [{'address_components': [{'long_name': '1', 's...
# 1     [{'address_components': [{'long_name': '5', 's...
# 2     [{'address_components': [{'long_name': 'Spring...
# 3     [{'address_components': [{'long_name': '1000',...
# 4     [{'address_components': [{'long_name': 'Cardif...
# ...                                                 ...
# 2738                                                NaN
# 2739                                                NaN
# 2740                                                NaN
# 2741                                                NaN
# 2742                                                NaN
#
#                                  coord   latitude   longitude duration  \
# 0           (37.3351874, -121.8810715)  37.335187 -121.881072  4 years
# 1             (53.5560114, 10.0227163)  53.556011   10.022716  3 years
# 2     (39.7301376, -89.61852689999999)  39.730138  -89.618527  4 years
# 3            (36.7993593, -76.1925395)  36.799359  -76.192539  4 years
# 4      (51.48662710000001, -3.1788641)  51.486627   -3.178864  3 years
# ...                                ...        ...         ...      ...
# 2738                               NaN   5.168048   -1.144657   1 year
# 2739                               NaN  14.392066  -16.958084   1 year
# 2740                               NaN -34.107178   18.470513   1 year
# 2741                               NaN  -6.445638   38.898731   1 year
# 2742                               NaN  -1.961283   30.112964   1 year
#
#                                           pretty_degree
# 0                 <b>Bachelor's (B.Sc.)</b> | In Person
# 1                 <b>Bachelor's (B.Sc.)</b> | In Person
# 2                 <b>Bachelor's (B.Sc.)</b> | In Person
# 3                 <b>Bachelor's (B.Sc.)</b> | In Person
# 4                 <b>Bachelor's (B.Sc.)</b> | In Person
# ...                                                 ...
# 2738  <b>Full-time Master's (AMMI)</b> | In Person &...
# 2739  <b>Full-time Master's (AMMI)</b> | In Person &...
# 2740  <b>Full-time Master's (AMMI)</b> | In Person &...
# 2741  <b>Full-time Master's (AMMI)</b> | In Person &...
# 2742  <b>Full-time Master's (AMMI)</b> | In Person &...
#
# [2460 rows x 20 columns]
